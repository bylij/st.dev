# %% [markdown]
# >https://ocw.mit.edu/courses/18-01sc-single-variable-calculus-fall-2010/resources/mit18_01scf10_ex07prb/
# >工具 https://ocw.mit.edu/ans7870/18/18.01SC/f10/mathlets/creatingDerivative.html

# %% [markdown]
# ### 问题
# - (a) $-\frac{3\pi}{2}$, $-\frac{\pi}{2}$, $\frac{\pi}{2}$, $\frac{3\pi}{2}$
# - (b) $-2\pi$, $0$, $2\pi$
# - (c) 这些斜率为正
# - (d) 手绘图：
# ![](data:image/png;base64,...)

# %% [markdown]
# - (e) 红色曲线为 $f^\prime(x)$ 真实图像，可以看到与 (d) 中的手绘图大体一致
# ![](data:image/png;base64,...)
